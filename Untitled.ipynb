# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv', sep = ',')

# %%
mf = df.groupby(['Protocol', 'Source', 'Dest_port', 'Sour_port']).count()

# %%
gg = pd.DataFrame(mf)

# %%
df.drop(['No.'], axis='columns')
# Out:
#          Time           Source      Destination Protocol  Dest_port  Sour_port
# 0    0.000000      192.168.1.2  185.199.110.154      TCP        443      65463
# 1    0.014217      192.168.1.2  151.101.244.133      TCP        443      65470
# 2    0.046057      192.168.1.2  185.199.110.154      TCP        443      65468
# 3    0.051506  185.199.110.154      192.168.1.2      TCP      65463        443
# 4    0.064958  151.101.244.133      192.168.1.2      TCP      65470        443
# 5    0.096736  185.199.110.154      192.168.1.2      TCP      65468        443
# 6    2.773108      192.168.1.2   213.180.193.60      TCP        443      64140
# 7    2.803408   213.180.193.60      192.168.1.2      TCP      64140        443
# 8    3.501008      192.168.1.2    51.158.86.207      TCP       2233      64178
# 9    3.582647    51.158.86.207      192.168.1.2      TCP      64178       2233
# 10   3.585251    51.158.86.207      192.168.1.2      TCP      64178       2233
# ...

# %%
df.to_csv('my_static.csv')
